# %%
import pandas as pd
# pan = panel
# da = data
# pandas -> panel data
# tabular data

# %%
print(pd.__version__)
# Out:
# 1.2.0

# %% [markdown]
# table -> DataFrame
# column -> Series
# row -> Index

# %%
df=pd.read_csv('bigmac_index.csv')
df[:5] # slice
# Out:
#          date iso_a3 currency_code       name  local_price  dollar_ex  \
# 0  2011-07-01    ARG           ARS  Argentina        20.00   4.132500
# 1  2011-07-01    AUS           AUD  Australia         4.56   0.922382
# 2  2011-07-01    BRA           BRL     Brazil         9.50   1.541600
# 3  2011-07-01    GBR           GBP    Britain         2.39   0.614137
# 4  2011-07-01    CAN           CAD     Canada         4.73   0.945850
#
#    dollar_price  GDP_dollar  adj_price      USD      EUR      GBP      JPY  \
# 0      4.839685    9138.177   3.149757  1.01089  0.47526  0.84970  0.90626
# 1      4.943724   55589.549   5.792526  0.11695 -0.18056  0.02742  0.05883
# 2      6.162429   10816.487   3.245241  1.48516  0.82320  1.28595  1.35584
# 3      3.891637   36119.846   4.684831  0.08714 -0.20243  0.00000  0.03058
# 4      5.000793   46214.914   5.259173  0.24443 -0.08704  0.14468  0.17968
#
#        CNY
# 0  0.94622
# 1  0.08103
# 2  1.40524
# 3  0.05218
# 4  0.20441

# %%
dx=pd.read_excel('bigmac_index.xlsx')
dx[-5:]
# Out:
#           date iso_a3 currency_code                  name  local_price  \
# 752 2021-01-01    UKR           UAH               Ukraine        62.00
# 753 2021-01-01    ARE           AED  United Arab Emirates        14.75
# 754 2021-01-01    USA           USD         United States         5.66
# 755 2021-01-01    URY           UYU               Uruguay       204.00
# 756 2021-01-01    VNM           VND               Vietnam     66000.00
#
#        dollar_ex  dollar_price  GDP_dollar  adj_price      USD      EUR  \
# 752     28.14000      2.203269    3706.765   3.014204 -0.28997 -0.36957
# 753      3.67315      4.015627   39179.883   4.445737 -0.12261 -0.22097
# 754      1.00000      5.660000   65253.518   5.497949  0.00000 -0.11211
# 755     42.49500      4.800565   16110.742   3.514772  0.32672  0.17798
# 756  23064.00000      2.861602    3416.232   3.002480 -0.07421 -0.17800
#
#          GBP      JPY      CNY
# 752 -0.24645 -0.12248 -0.30700
# 753 -0.06884  0.08436 -0.14366
# ...

# %%
dx[0:4]
# Out:
#         date iso_a3 currency_code       name  local_price  dollar_ex  \
# 0 2011-07-01    ARG           ARS  Argentina        20.00   4.132500
# 1 2011-07-01    AUS           AUD  Australia         4.56   0.922382
# 2 2011-07-01    BRA           BRL     Brazil         9.50   1.541600
# 3 2011-07-01    GBR           GBP    Britain         2.39   0.614137
#
#    dollar_price  GDP_dollar  adj_price      USD      EUR      GBP      JPY  \
# 0      4.839685    9138.177   3.149757  1.01089  0.47526  0.84970  0.90626
# 1      4.943724   55589.549   5.792526  0.11695 -0.18056  0.02742  0.05883
# 2      6.162429   10816.487   3.245241  1.48516  0.82320  1.28595  1.35584
# 3      3.891637   36119.846   4.684831  0.08714 -0.20243  0.00000  0.03058
#
#        CNY
# 0  0.94622
# 1  0.08103
# 2  1.40524
# 3  0.05218

# %%
dx[1:4]
# Out:
#         date iso_a3 currency_code       name  local_price  dollar_ex  \
# 1 2011-07-01    AUS           AUD  Australia         4.56   0.922382
# 2 2011-07-01    BRA           BRL     Brazil         9.50   1.541600
# 3 2011-07-01    GBR           GBP    Britain         2.39   0.614137
#
#    dollar_price  GDP_dollar  adj_price      USD      EUR      GBP      JPY  \
# 1      4.943724   55589.549   5.792526  0.11695 -0.18056  0.02742  0.05883
# 2      6.162429   10816.487   3.245241  1.48516  0.82320  1.28595  1.35584
# 3      3.891637   36119.846   4.684831  0.08714 -0.20243  0.00000  0.03058
#
#        CNY
# 1  0.08103
# 2  1.40524
# 3  0.05218

# %%
cols=['date', 'name', 'dollar_price']
cols
# Out:
# ['date', 'name', 'dollar_price']

# %%
dx[cols][:5]
# Out:
#         date       name  dollar_price
# 0 2011-07-01  Argentina      4.839685
# 1 2011-07-01  Australia      4.943724
# 2 2011-07-01     Brazil      6.162429
# 3 2011-07-01    Britain      3.891637
# 4 2011-07-01     Canada      5.000793

# %%
dx[:5][cols]
# Out:
#         date       name  dollar_price
# 0 2011-07-01  Argentina      4.839685
# 1 2011-07-01  Australia      4.943724
# 2 2011-07-01     Brazil      6.162429
# 3 2011-07-01    Britain      3.891637
# 4 2011-07-01     Canada      5.000793

# %%
dx[dx['name']=='Thailand']
# Out:
#           date iso_a3 currency_code      name  local_price  dollar_ex  \
# 34  2011-07-01    THA           THB  Thailand         70.0    29.7500
# 71  2012-01-01    THA           THB  Thailand         78.0    31.7500
# 107 2012-07-01    THA           THB  Thailand         82.0    31.7000
# 144 2013-01-01    THA           THB  Thailand         87.0    29.7550
# 181 2013-07-01    THA           THB  Thailand         89.0    31.2750
# 218 2014-01-01    THA           THB  Thailand         96.0    32.8750
# 255 2014-07-01    THA           THB  Thailand         99.0    31.7800
# 292 2015-01-01    THA           THB  Thailand         99.0    32.6050
# 329 2015-07-01    THA           THB  Thailand        108.0    34.0875
# 366 2016-01-01    THA           THB  Thailand        112.0    36.2200
# 403 2016-07-01    THA           THB  Thailand        119.0    34.9650
# 440 2017-01-01    THA           THB  Thailand        119.0    35.5730
# ...

# %%
dx.corr()
# Out:
#               local_price  dollar_ex  dollar_price  GDP_dollar  adj_price  \
# local_price      1.000000   0.989947     -0.146257   -0.202777  -0.196193
# dollar_ex        0.989947   1.000000     -0.160481   -0.193742  -0.189360
# dollar_price    -0.146257  -0.160481      1.000000    0.761314   0.779613
# GDP_dollar      -0.202777  -0.193742      0.761314    1.000000   0.973527
# adj_price       -0.196193  -0.189360      0.779613    0.973527   1.000000
# USD             -0.003329  -0.040012      0.576189   -0.026388   0.030351
# EUR             -0.002965  -0.038175      0.585923   -0.012122  -0.023308
# GBP              0.002880  -0.033747      0.579290   -0.024548  -0.003239
# JPY             -0.000216  -0.035335      0.574867   -0.004241   0.022242
# CNY             -0.006086  -0.042394      0.584449   -0.019766   0.014437
#
#                    USD       EUR       GBP       JPY       CNY
# local_price  -0.003329 -0.002965  0.002880 -0.000216 -0.006086
# ...

# %%
dx.hist(figsize=(10, 10));
