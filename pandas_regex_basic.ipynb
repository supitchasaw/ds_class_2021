# %% [markdown]
# # pandas: basic regular expression

# %% [markdown]
# ---
# * author:  [Prasert Kanawattanachai](prasert.k@chula.ac.th)
# * YouTube: https://www.youtube.com/prasertcbs
# * [Chulalongkorn Business School](https://www.cbs.chula.ac.th/en/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('KTGvdg9c_qU', width=720, height=405)

# %%
import pandas as pd

# pd.set_option('display.max_rows', 50)

import warnings
warnings.filterwarnings('ignore')

# %%
print(f'pandas version: {pd.__version__}')

pd.Timestamp.now()
# Out:
# pandas version: 1.2.0
# Timestamp('2021-02-03 10:54:52.212966')

# %%
url='https://github.com/prasertcbs/basic-dataset/raw/master/IMDBtop1000.csv'
df=pd.read_csv(url, usecols=['Title', 'Actors'])
df
# Out:
#                        Title  \
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# ..                       ...
# 995     Secret in Their Eyes
# 996          Hostel: Part II
# 997   Step Up 2: The Streets
# 998             Search Party
# 999               Nine Lives
#
#                                                 Actors
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...
# ..                                                 ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996  Lauren German, Heather Matarazzo, Bijou Philli...
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# ...

# %%
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
pd.set_option('display.max_colwidth', None)

# %%
# Series.str.contains
df['Actors'].str.contains('vin diesel', case=False)

# %%
# filter
df[df['Actors'].str.contains('vin diesel', case=False)] # ilike '%Vin Diesel%'
# Out:
#                        Title  \
# 0    Guardians of the Galaxy
# 84             Furious Seven
# 134                Furious 6
# 319                Fast Five
# 325    The Last Witch Hunter
# 340           Fast & Furious
# 944                  Riddick
#
#                                                             Actors
# 0             Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana
# 84          Vin Diesel, Paul Walker, Dwayne Johnson, Jason Statham
# 134    Vin Diesel, Paul Walker, Dwayne Johnson, Michelle Rodriguez
# 319      Vin Diesel, Paul Walker, Dwayne Johnson, Jordana Brewster
# 325    Vin Diesel, Rose Leslie, Elijah Wood, Ólafur Darri Ólafsson
# 340  Vin Diesel, Paul Walker, Michelle Rodriguez, Jordana Brewster
# 944            Vin Diesel, Karl Urban, Katee Sackhoff, Jordi Mollà

# %%
# filter
df[df['Title'].str.match('Go', case=False)] # ilike '%Vin Diesel%'
# Out:
#               Title  \
# 20             Gold
# 83        Gone Girl
# 215   Gods of Egypt
# 464      Goosebumps
# 528        Godzilla
# 662  Gone Baby Gone
# 915         Goksung
# 928       Good Kids
#
#                                                                        Actors
# 20       Matthew McConaughey, Edgar Ramírez, Bryce Dallas Howard, Corey Stoll
# 83                Ben Affleck, Rosamund Pike, Neil Patrick Harris,Tyler Perry
# 215  Brenton Thwaites, Nikolaj Coster-Waldau, Gerard Butler, Chadwick Boseman
# 464                          Jack Black, Dylan Minnette, Odeya Rush, Ryan Lee
# 528       Aaron Taylor-Johnson, Elizabeth Olsen, Bryan Cranston, Ken Watanabe
# 662               Morgan Freeman, Ed Harris, Casey Affleck, Michelle Monaghan
# 915                   Jun Kunimura, Jung-min Hwang, Do-won Kwak, Woo-hee Chun
# 928                Zoey Deutch, Nicholas Braun, Mateo Arias, Israel Broussard

# %%
# \d digit
df[df['Title'].str.contains(r'\d{4}', case=False)] # r'' -> raw format
# Out:
#                     Title  \
# 472                  2012
# 616  2307: Winter's Dream
# 804                  1408
#
#                                                             Actors
# 472      John Cusack, Thandie Newton, Chiwetel Ejiofor,Amanda Peet
# 616       Paul Sidhu, Branden Coles, Arielle Holmes, Kelcey Watson
# 804  John Cusack, Samuel L. Jackson, Mary McCormack, Paul Birchard

# %%
# \d digit
df[df['Title'].str.contains(r'\d{4}$', case=False)] # r'' -> raw format
# Out:
#     Title                                                         Actors
# 472  2012      John Cusack, Thandie Newton, Chiwetel Ejiofor,Amanda Peet
# 804  1408  John Cusack, Samuel L. Jackson, Mary McCormack, Paul Birchard

# %%
# \d digit
df[df['Title'].str.contains(r'^\d', case=False)] # r'' -> raw format
# Out:
#                       Title  \
# 39                5- 25- 77
# 111        12 Years a Slave
# 113                     300
# 118     10 Cloverfield Lane
# 168                13 Hours
# 247      20th Century Women
# 272          21 Jump Street
# 276          22 Jump Street
# 423  300: Rise of an Empire
# 430                3 Idiots
# 472                    2012
# 616    2307: Winter's Dream
# 696                10 Years
# 776                      31
# 804                    1408
# 817               127 Hours
# 849                      42
# 850                      21
# 875          28 Weeks Later
# 889                   50/50
# 922                17 Again
# 958          3 Days to Kill
#
#                                                                             Actors
# 39                  John Francis Daley, Austin Pendleton, Colleen Camp, Neil Flynn
# 111      Chiwetel Ejiofor, Michael Kenneth Williams, Michael Fassbender, Brad Pitt
# ...

# %%
df[df['Title'].str.contains('man')] # case sensitive

# %%
df[df['Title'].str.contains('Man')]

# %%
df[df['Title'].str.contains(r'man', case=False)]

# %% [markdown]
# ## starts with

# %%
df[df['Title'].str.contains(r'^man', case=False)]
# Out:
#                      Title  \
# 21   Manchester by the Sea
# 294           Man of Steel
# 794         Man on a Ledge
# 824               Man Down
#
#                                                            Actors
# 21   Casey Affleck, Michelle Williams, Kyle Chandler,Lucas Hedges
# 294          Henry Cavill, Amy Adams, Michael Shannon, Diane Lane
# 794  Sam Worthington, Elizabeth Banks, Jamie Bell, Mandy Gonzalez
# 824            Shia LaBeouf, Jai Courtney, Gary Oldman, Kate Mara

# %%
df[df['Title'].str.contains(r'^man\b', case=False)] # \b  ;,: word boundery
# Out:
#               Title  \
# 294    Man of Steel
# 794  Man on a Ledge
# 824        Man Down
#
#                                                            Actors
# 294          Henry Cavill, Amy Adams, Michael Shannon, Diane Lane
# 794  Sam Worthington, Elizabeth Banks, Jamie Bell, Mandy Gonzalez
# 824            Shia LaBeouf, Jai Courtney, Gary Oldman, Kate Mara

# %% [markdown]
# ## ends with

# %%
df[df['Title'].str.contains(r'man$', case=False)]

# %% [markdown]
# ## word boundary

# %%
df[df['Title'].str.contains(r'man', case=False)]

# %% [markdown]
# ## raw string

# %%
df[df['Title'].str.contains('man\b', case=False)] # case insenstive comparison
# Out:
# Empty DataFrame
# Columns: [Title, Actors]
# Index: []

# %%
regular expression pattern

# %%
df[df['Title'].str.contains(r'man\b', case=False)] # case insenstive comparison
# Out:
#                                                              Title  \
# 60                              Batman v Superman: Dawn of Justice
# 65                                    Kingsman: The Secret Service
# 78                      Pirates of the Caribbean: Dead Man's Chest
# 104                                        The Man from U.N.C.L.E.
# 167                                                  Woman in Gold
# 179                                                        Ant-Man
# 203                                                       Iron Man
# 234                                     The Huntsman: Winter's War
# 253                                       The Amazing Spider-Man 2
# 259  Norman: The Moderate Rise and Tragic Fall of a New York Fixer
# 260                Birdman or (The Unexpected Virtue of Ignorance)
# 279                                                 Iron Man Three
# 294                                                   Man of Steel
# ...

# %%
\b
\d - 0123456789
\w
\
raw string - \b boundery

# %%
df[df['Title'].str.contains(r'man\b', case=False)] # case insenstive comparison
# Out:
#                                                              Title  \
# 60                              Batman v Superman: Dawn of Justice
# 65                                    Kingsman: The Secret Service
# 78                      Pirates of the Caribbean: Dead Man's Chest
# 104                                        The Man from U.N.C.L.E.
# 167                                                  Woman in Gold
# 179                                                        Ant-Man
# 203                                                       Iron Man
# 234                                     The Huntsman: Winter's War
# 253                                       The Amazing Spider-Man 2
# 259  Norman: The Moderate Rise and Tragic Fall of a New York Fixer
# 260                Birdman or (The Unexpected Virtue of Ignorance)
# 279                                                 Iron Man Three
# 294                                                   Man of Steel
# ...

# %%
df[df['Title'].str.contains(r'man\b', case=False)] # case insenstive comparison

# %%
df[df['Title'].str.contains(r'\bman$', case=False)] # r' (raw string)

# %%
df[df['Title'].str.contains(r'^man', case=False)]

# %%
df[df['Title'].str.contains(r'^man\b', case=False)]

# %%
df[df['Title'].str.contains(r'man\b', case=False)] # man + punctuation marks

# %%
df[df['Title'].str.contains(r'man\b$', case=False)]

# %%
df[df['Title'].str.contains(r'\bman\b', case=False)]

# %% [markdown]
# ## match one of a set of characters [aeiou]

# %%
# df[df['Title'].str.contains(r'[1234you]', case=False)]
df[df['Title'].str.contains(r'\bman\b', case=False)] # select on 'z' or 'e' or 'i' or 'o' or 'u'
# Out:
#                                           Title  \
# 78   Pirates of the Caribbean: Dead Man's Chest
# 104                     The Man from U.N.C.L.E.
# 179                                     Ant-Man
# 203                                    Iron Man
# 253                    The Amazing Spider-Man 2
# 279                              Iron Man Three
# 294                                Man of Steel
# 344                                Spider-Man 3
# 368                      The Amazing Spider-Man
# 378                              Swiss Army Man
# 450                                  Iron Man 2
# 593                               She's the Man
# 779                   The Man Who Knew Infinity
# 794                              Man on a Ledge
# 815                                  Inside Man
# 824                                    Man Down
# 870                        En man som heter Ove
#
#                                                                    Actors
# ...

# %%
df[(df['Title'].str.contains(r'man', case=False)) & (df['Title'].str.contains(r'2', case=False))]
# Out:
#                         Title  \
# 253  The Amazing Spider-Man 2
# 450                Iron Man 2
#
#                                                             Actors
# 253         Andrew Garfield, Emma Stone, Jamie Foxx, Paul Giamatti
# 450  Robert Downey Jr., Mickey Rourke, Gwyneth Paltrow,Don Cheadle

# %%
df[(df['Title'].str.contains(r'\bman\b', case=False))]
# Out:
#                                           Title  \
# 78   Pirates of the Caribbean: Dead Man's Chest
# 104                     The Man from U.N.C.L.E.
# 179                                     Ant-Man
# 203                                    Iron Man
# 253                    The Amazing Spider-Man 2
# 279                              Iron Man Three
# 294                                Man of Steel
# 344                                Spider-Man 3
# 368                      The Amazing Spider-Man
# 378                              Swiss Army Man
# 450                                  Iron Man 2
# 593                               She's the Man
# 779                   The Man Who Knew Infinity
# 794                              Man on a Ledge
# 815                                  Inside Man
# 824                                    Man Down
# 870                        En man som heter Ove
#
#                                                                    Actors
# ...

# %%
df[df['Title'].str.contains(r'wom[ae]n$', case=False)] # title like '%woman%' or title like '%women%'
# Out:
#                   Title  \
# 247  20th Century Women
# 570     The Other Woman
#
#                                                            Actors
# 247      Annette Bening, Elle Fanning, Greta Gerwig, Billy Crudup
# 570  Cameron Diaz, Leslie Mann, Kate Upton, Nikolaj Coster-Waldau

# %%
df[df['Title'].str.contains(r'colo[u*]r', case=False)]
# Out:
# Empty DataFrame
# Columns: [Title, Actors]
# Index: []

# %%
* {0, }
? {0, 1}
+ {1, }

# %% [markdown]
# ## OR

# %%
df[df['Title'].str.contains(r'\bbatman|spider|\bant\b|iron', case=False)]
# Out:
#                                   Title  \
# 60   Batman v Superman: Dawn of Justice
# 179                             Ant-Man
# 203                            Iron Man
# 253            The Amazing Spider-Man 2
# 279                      Iron Man Three
# 344                        Spider-Man 3
# 368              The Amazing Spider-Man
# 450                          Iron Man 2
# 471                    Marie Antoinette
# 520                          Anthropoid
# 622                          Antichrist
#
#                                                                 Actors
# 60               Ben Affleck, Henry Cavill, Amy Adams, Jesse Eisenberg
# 179          Paul Rudd, Michael Douglas, Corey Stoll, Evangeline Lilly
# 203  Robert Downey Jr., Gwyneth Paltrow, Terrence Howard, Jeff Bridges
# 253             Andrew Garfield, Emma Stone, Jamie Foxx, Paul Giamatti
# 279         Robert Downey Jr., Guy Pearce, Gwyneth Paltrow,Don Cheadle
# ...

# %%
df[df['Title'].str.contains(r'^batman|^spider|^ant|^iron', case=False)]
# Out:
#                                   Title  \
# 60   Batman v Superman: Dawn of Justice
# 179                             Ant-Man
# 203                            Iron Man
# 279                      Iron Man Three
# 344                        Spider-Man 3
# 450                          Iron Man 2
# 520                          Anthropoid
# 622                          Antichrist
#
#                                                                 Actors
# 60               Ben Affleck, Henry Cavill, Amy Adams, Jesse Eisenberg
# 179          Paul Rudd, Michael Douglas, Corey Stoll, Evangeline Lilly
# 203  Robert Downey Jr., Gwyneth Paltrow, Terrence Howard, Jeff Bridges
# 279         Robert Downey Jr., Guy Pearce, Gwyneth Paltrow,Don Cheadle
# 344    Tobey Maguire, Kirsten Dunst, Topher Grace, Thomas Haden Church
# 450      Robert Downey Jr., Mickey Rourke, Gwyneth Paltrow,Don Cheadle
# 520      Jamie Dornan, Cillian Murphy, Brian Caspe, Karel Hermánek Jr.
# ...

# %%
df[df['Title'].str.contains(r'^(batman|spider|ant|iron)', case=False)]
# Out:
#                                   Title  \
# 60   Batman v Superman: Dawn of Justice
# 179                             Ant-Man
# 203                            Iron Man
# 279                      Iron Man Three
# 344                        Spider-Man 3
# 450                          Iron Man 2
# 520                          Anthropoid
# 622                          Antichrist
#
#                                                                 Actors
# 60               Ben Affleck, Henry Cavill, Amy Adams, Jesse Eisenberg
# 179          Paul Rudd, Michael Douglas, Corey Stoll, Evangeline Lilly
# 203  Robert Downey Jr., Gwyneth Paltrow, Terrence Howard, Jeff Bridges
# 279         Robert Downey Jr., Guy Pearce, Gwyneth Paltrow,Don Cheadle
# 344    Tobey Maguire, Kirsten Dunst, Topher Grace, Thomas Haden Church
# 450      Robert Downey Jr., Mickey Rourke, Gwyneth Paltrow,Don Cheadle
# 520      Jamie Dornan, Cillian Murphy, Brian Caspe, Karel Hermánek Jr.
# ...

# %%
df[df['Title'].str.contains(r'(batman|spider|ant|iron)$', case=False)]
# Out:
#               Title  \
# 89   The Accountant
# 129    The Revenant
# 204       Allegiant
#
#                                                            Actors
# 89         Ben Affleck, Anna Kendrick, J.K. Simmons, Jon Bernthal
# 129  Leonardo DiCaprio, Tom Hardy, Will Poulter, Domhnall Gleeson
# 204        Shailene Woodley, Theo James, Jeff Daniels,Naomi Watts

# %%
\s -> white space (space, tab)
* {0, }

# %%
[a-f]

# %%
df[df['Title'].str.contains(r'(bat|spider|ant|iron)[\-\s]*man', case=False)]
# Out:
#                                   Title  \
# 60   Batman v Superman: Dawn of Justice
# 179                             Ant-Man
# 203                            Iron Man
# 253            The Amazing Spider-Man 2
# 279                      Iron Man Three
# 344                        Spider-Man 3
# 368              The Amazing Spider-Man
# 450                          Iron Man 2
#
#                                                                 Actors
# 60               Ben Affleck, Henry Cavill, Amy Adams, Jesse Eisenberg
# 179          Paul Rudd, Michael Douglas, Corey Stoll, Evangeline Lilly
# 203  Robert Downey Jr., Gwyneth Paltrow, Terrence Howard, Jeff Bridges
# 253             Andrew Garfield, Emma Stone, Jamie Foxx, Paul Giamatti
# 279         Robert Downey Jr., Guy Pearce, Gwyneth Paltrow,Don Cheadle
# 344    Tobey Maguire, Kirsten Dunst, Topher Grace, Thomas Haden Church
# 368               Andrew Garfield, Emma Stone, Rhys Ifans, Irrfan Khan
# ...

# %%
df[df['Title'].str.contains(r'(bat|spider|ant|iron)\s*man', case=False)]

# %%
df[df['Title'].str.contains(r'(bat|spider|ant|iron)[\-\s]*man', case=False)]
# Out:
#                                   Title  \
# 60   Batman v Superman: Dawn of Justice
# 179                             Ant-Man
# 203                            Iron Man
# 253            The Amazing Spider-Man 2
# 279                      Iron Man Three
# 344                        Spider-Man 3
# 368              The Amazing Spider-Man
# 450                          Iron Man 2
#
#                                                                 Actors
# 60               Ben Affleck, Henry Cavill, Amy Adams, Jesse Eisenberg
# 179          Paul Rudd, Michael Douglas, Corey Stoll, Evangeline Lilly
# 203  Robert Downey Jr., Gwyneth Paltrow, Terrence Howard, Jeff Bridges
# 253             Andrew Garfield, Emma Stone, Jamie Foxx, Paul Giamatti
# 279         Robert Downey Jr., Guy Pearce, Gwyneth Paltrow,Don Cheadle
# 344    Tobey Maguire, Kirsten Dunst, Topher Grace, Thomas Haden Church
# 368               Andrew Garfield, Emma Stone, Rhys Ifans, Irrfan Khan
# ...

# %% [markdown]
# ## group

# %%
df[df['Title'].str.contains(r'^bat|^spider|^iron|^ant', case=False)]

# %%
df[df['Title'].str.contains(r'^(bat|spider|iron|ant)', case=False)]

# %% [markdown]
# ## \d for digit

# %%
df[df['Title'].str.contains(r'\d', case=False)]

# %%
df[df['Title'].str.contains(r'[0-9]', case=False)]

# %%
df[df['Title'].str.contains(r'\d{2}', case=False)]

# %%
df[df['Title'].str.contains(r'\d{2}$', case=False)]

# %%
df[df['Title'].str.contains(r'(3|iii|three)$', case=False)]

# %%
df[df['Title'].str.contains(r'\b(3|iii|three)$', case=False)]

# %%
df[(df['Title'].str.contains('iron|avenger', case=False)) & (df['Actors'].str.contains('chris', case=False))]

# %% [markdown]
# ## AND with lookahead ?=

# %%
df[df['Actors'].str.contains('.*Downey.*Evans', case=False)]

# %%
df[df['Actors'].str.contains('.*Evans.*Downey', case=False)]

# %%
df[df['Actors'].str.contains('(.*Evans.*Downey)|(.*Downey.*Evans)', case=False)]

# %%
df[df['Actors'].str.contains('(?=.*Downey)(?=.*Evans)', case=False)]

# %%
df[df['Actors'].str.contains('(?=.*Evans)(?=.*Downey)', case=False)]

# %% [markdown]
# ## quantifiers
# ```
# - *, ?, +
# - a* -> a{0,}
# - a+ -> a{1,}
# - a? -> a{0,1}
# ```

# %%
df[df['Title'].str.contains(r'\bi{2}\b', case=False)]
# Out:
#                            Title  \
# 206                     Raw (II)
# 609  Hellboy II: The Golden Army
# 720        Nymphomaniac: Vol. II
# 996              Hostel: Part II
#
#                                                                 Actors
# 206    Garance Marillier, Ella Rumpf, Rabah Nait Oufella,Laurent Lucas
# 609               Ron Perlman, Selma Blair, Doug Jones, John Alexander
# 720  Charlotte Gainsbourg, Stellan Skarsgård, Willem Dafoe, Jamie Bell
# 996       Lauren German, Heather Matarazzo, Bijou Phillips, Roger Bart

# %%
df[df['Title'].str.contains(r'i{0,}', case=False)]
# Out:
#                        Title  \
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# ..                       ...
# 995     Secret in Their Eyes
# 996          Hostel: Part II
# 997   Step Up 2: The Streets
# 998             Search Party
# 999               Nine Lives
#
#                                                                          Actors
# 0                          Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana
# 1       Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron
# 2              James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula
# 3    Matthew McConaughey,Reese Witherspoon, Seth MacFarlane, Scarlett Johansson
# 4                            Will Smith, Jared Leto, Margot Robbie, Viola Davis
# ..                                                                          ...
# ...

# %%
df[:5]
# Out:
#                      Title  \
# 0  Guardians of the Galaxy
# 1               Prometheus
# 2                    Split
# 3                     Sing
# 4            Suicide Squad
#
#                                                                        Actors
# 0                        Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana
# 1     Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron
# 2            James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula
# 3  Matthew McConaughey,Reese Witherspoon, Seth MacFarlane, Scarlett Johansson
# 4                          Will Smith, Jared Leto, Margot Robbie, Viola Davis

# %%
a=df['Actors'].str.split(', ')
a
# Out:
# 0                            [Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana]
# 1         [Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron]
# 2                [James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula]
# 3      [Matthew McConaughey,Reese Witherspoon, Seth MacFarlane, Scarlett Johansson]
# 4                              [Will Smith, Jared Leto, Margot Robbie, Viola Davis]
#                                            ...
# 995                   [Chiwetel Ejiofor, Nicole Kidman, Julia Roberts, Dean Norris]
# 996                  [Lauren German, Heather Matarazzo, Bijou Phillips, Roger Bart]
# 997                 [Robert Hoffman, Briana Evigan, Cassie Ventura, Adam G. Sevani]
# 998                  [Adam Pally, T.J. Miller, Thomas Middleditch,Shannon Woodward]
# 999                      [Kevin Spacey, Jennifer Garner, Robbie Amell,Cheryl Hines]
# Name: Actors, Length: 1000, dtype: object

# %%
a[0]
# Out:
# ['Chris Pratt', 'Vin Diesel', 'Bradley Cooper', 'Zoe Saldana']

# %%
a[3]
# Out:
# ['Matthew McConaughey,Reese Witherspoon',
#  'Seth MacFarlane',
#  'Scarlett Johansson']

# %%
b=df['Actors'].str.split(r',\s*')
b
# Out:
# 0                             [Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana]
# 1          [Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron]
# 2                 [James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula]
# 3      [Matthew McConaughey, Reese Witherspoon, Seth MacFarlane, Scarlett Johansson]
# 4                               [Will Smith, Jared Leto, Margot Robbie, Viola Davis]
#                                            ...
# 995                    [Chiwetel Ejiofor, Nicole Kidman, Julia Roberts, Dean Norris]
# 996                   [Lauren German, Heather Matarazzo, Bijou Phillips, Roger Bart]
# 997                  [Robert Hoffman, Briana Evigan, Cassie Ventura, Adam G. Sevani]
# 998                  [Adam Pally, T.J. Miller, Thomas Middleditch, Shannon Woodward]
# 999                      [Kevin Spacey, Jennifer Garner, Robbie Amell, Cheryl Hines]
# Name: Actors, Length: 1000, dtype: object

# %%
b[0]
# Out:
# ['Chris Pratt', 'Vin Diesel', 'Bradley Cooper', 'Zoe Saldana']

# %%
b[3]
# Out:
# ['Matthew McConaughey',
#  'Reese Witherspoon',
#  'Seth MacFarlane',
#  'Scarlett Johansson']

# %%
# str
s='Peter Parker, Julia Roberts'

# %%
s.split(', ')
# Out:
# ['Peter Parker', 'Julia Roberts']
