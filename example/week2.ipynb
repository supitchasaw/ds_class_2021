# %%
import pandas as pd

# %%
print(f'pandas version = {pd.__version__}')
# Out:
# pandas version = 1.2.0

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2021-01-27 09:09:28.214572')

# %% [markdown]
# # read data

# %%
df=pd.read_csv('nutrients.csv')
df
# Out:
#                       Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0               Cows' milk   1 qt.    976      660      32  40      36     0
# 1                Milk skim   1 qt.    984      360      36   t       t     0
# 2               Buttermilk   1 cup    246      127       9   5       4     0
# 3    Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4           Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
# ..                     ...     ...    ...      ...     ...  ..     ...   ...
# 330    Fruit-flavored soda  12 oz.    346      161       0   0       0     0
# 331             Ginger ale  12 oz.    346      105       0   0       0     0
# 332              Root beer  12 oz.    346      140       0   0       0     0
# 333                 Coffee   1 cup    230        3       t   0       0     0
# 334                    Tea   1 cup    230        4       0   t       0     0
#
#     Carbs                   Category
# ...

# %%
df[2:10] # slicing - exclusive range(10) -> [0, 9]
# Out:
#                     Food     Measure  Grams Calories Protein Fat Sat.Fat  \
# 2             Buttermilk       1 cup    246      127       9   5       4
# 3  Evaporated, undiluted       1 cup    252      345      16  20      18
# 4         Fortified milk      6 cups  1,419    1,373      89  42      23
# 5          Powdered milk       1 cup    103      515      27  28      24
# 6          skim, instant  1 1/3 cups     85      290      30   t       t
# 7      skim, non-instant     2/3 cup     85      290      30   t       t
# 8            Goats' milk       1 cup    244      165       8  10       8
# 9    (1/2 cup ice cream)      2 cups    540      690      24  24      22
#
#   Fiber Carbs        Category
# 2     0    13  Dairy products
# 3     0    24  Dairy products
# 4   1.4   119  Dairy products
# 5     0    39  Dairy products
# 6     0    42  Dairy products
# 7     1    42  Dairy products
# 8     0    11  Dairy products
# 9     0    70  Dairy products

# %% [markdown]
# ## Series

# %%
df.Food # dot notation
# Out:
# 0                 Cows' milk
# 1                  Milk skim
# 2                 Buttermilk
# 3      Evaporated, undiluted
# 4             Fortified milk
#                ...
# 330      Fruit-flavored soda
# 331               Ginger ale
# 332                Root beer
# 333                   Coffee
# 334                      Tea
# Name: Food, Length: 335, dtype: object

# %%
df['Food'] # bracket Series
# Out:
# 0                 Cows' milk
# 1                  Milk skim
# 2                 Buttermilk
# 3      Evaporated, undiluted
# 4             Fortified milk
#                ...
# 330      Fruit-flavored soda
# 331               Ginger ale
# 332                Root beer
# 333                   Coffee
# 334                      Tea
# Name: Food, Length: 335, dtype: object

# %%
df[['Food', 'Sat.Fat']][:3] # bracket DataFrame
# Out:
#          Food Sat.Fat
# 0  Cows' milk      36
# 1   Milk skim       t
# 2  Buttermilk       4

# %%
df[:3][['Food', 'Sat.Fat']] # bracket DataFrame
# Out:
#          Food Sat.Fat
# 0  Cows' milk      36
# 1   Milk skim       t
# 2  Buttermilk       4

# %%
df['Sat.Fat'] # case sensitive
# Out:
# 0      36
# 1       t
# 2       4
# 3      18
# 4      23
#        ..
# 330     0
# 331     0
# 332     0
# 333     0
# 334     0
# Name: Sat.Fat, Length: 335, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Food      335 non-null    object
#  1   Measure   335 non-null    object
#  2   Grams     335 non-null    object
#  3   Calories  334 non-null    object
#  4   Protein   335 non-null    object
#  5   Fat       335 non-null    object
#  6   Sat.Fat   333 non-null    object
#  7   Fiber     335 non-null    object
#  8   Carbs     335 non-null    object
#  9   Category  335 non-null    object
# dtypes: object(10)
# memory usage: 26.3+ KB

# %%
data=pd.read_csv('https://github.com/prasertcbs/ds_class_2021/raw/week2/Telco-Customer-Churn.csv', nrows=20)
data[:3]
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        20 non-null     object
#  1   gender            20 non-null     object
#  2   SeniorCitizen     20 non-null     int64
#  3   Partner           20 non-null     object
#  4   Dependents        20 non-null     object
#  5   tenure            20 non-null     int64
#  6   PhoneService      20 non-null     object
#  7   MultipleLines     20 non-null     object
#  8   InternetService   20 non-null     object
#  9   OnlineSecurity    20 non-null     object
#  10  OnlineBackup      20 non-null     object
#  11  DeviceProtection  20 non-null     object
#  12  TechSupport       20 non-null     object
#  13  StreamingTV       20 non-null     object
#  14  StreamingMovies   20 non-null     object
#  15  Contract          20 non-null     object
# ...

# %%
data.sample(frac=.1) # fraction 10%
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 845   0422-OHQHQ  Female              0     Yes        Yes      15
# 5291  1334-PDUKM  Female              0     Yes         No      68
# 571   7025-WCBNE    Male              1      No         No      47
# 684   8040-MNRTF  Female              0      No         No       1
# 5913  6156-UZDLF  Female              0      No         No      26
# ...          ...     ...            ...     ...        ...     ...
# 6391  4000-VGMQP    Male              0     Yes        Yes      38
# 1821  3536-IQCTX    Male              1     Yes         No      32
# 2517  5186-SAMNZ    Male              1      No         No       1
# 2763  2250-IVBWA    Male              0     Yes        Yes      64
# 1935  7297-DVYGA  Female              0      No         No      51
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 845           Yes            No              No  No internet service  ...
# ...

# %%
data[:3].T # transpose
# Out:
#                                  0             1               2
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
baskin=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/BaskinRobbins.tsv', sep='\t')
baskin
# Out:
#                      Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0             Bananas Foster       160            8.0            0.2
# 1               Baseball Nut       160            9.0            0.2
# 2         Beavertails Pastry       170            9.0            0.3
# 3   Blackberry Frozen Yogurt       120            4.0            0.1
# 4     Blue Raspberry Sherbet       130            2.0            0.1
# ..                       ...       ...            ...            ...
# 65     Very Berry Strawberry       200           10.0            0.4
# 66         Watermelon Splash       120            0.5            0.0
# 67          Wild ‘n Reckless        80            1.5            0.0
# 68    Winter White Chocolate       160            8.0            0.2
# 69     World Class Chocolate       260           60.0            0.4
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)  Sugar Alcohol (g)
# 0                  20          16          2.0                NaN
# ...

# %%
baskin2=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/BaskinRobbins.tsv', sep='\t', index_col=['Flavour'])
baskin2
# Out:
#                           Calories  Total Fat (g)  Trans Fat (g)  \
# Flavour
# Bananas Foster                 160            8.0            0.2
# Baseball Nut                   160            9.0            0.2
# Beavertails Pastry             170            9.0            0.3
# Blackberry Frozen Yogurt       120            4.0            0.1
# Blue Raspberry Sherbet         130            2.0            0.1
# ...                            ...            ...            ...
# Very Berry Strawberry          200           10.0            0.4
# Watermelon Splash              120            0.5            0.0
# Wild ‘n Reckless                80            1.5            0.0
# Winter White Chocolate         160            8.0            0.2
# World Class Chocolate          260           60.0            0.4
#
#                           Carbohydrates (g)  Sugars (g)  Protein (g)  \
# Flavour
# Bananas Foster                           20          16          2.0
# ...

# %%
baskin2.loc['Bananas Foster'] # locate label index
# Out:
# Calories             160.0
# Total Fat (g)          8.0
# Trans Fat (g)          0.2
# Carbohydrates (g)     20.0
# Sugars (g)            16.0
# Protein (g)            2.0
# Sugar Alcohol (g)      NaN
# Name: Bananas Foster, dtype: float64

# %%
baskin2.loc[['Bananas Foster']] # locate label index
# Out:
#                 Calories  Total Fat (g)  Trans Fat (g)  Carbohydrates (g)  \
# Flavour
# Bananas Foster       160            8.0            0.2                 20
#
#                 Sugars (g)  Protein (g)  Sugar Alcohol (g)
# Flavour
# Bananas Foster          16          2.0                NaN

# %%
baskin2.loc[
    ['Bananas Foster', 'World Class Chocolate'], 
    ['Calories', 'Sugars (g)']
] # locate label index
# Out:
#                        Calories  Sugars (g)
# Flavour
# Bananas Foster              160          16
# World Class Chocolate       260          18

# %%
baskin2.loc[
    ['Bananas Foster', 'World Class Chocolate'], 
    'Calories':'Trans Fat (g)'
] # locate label index
# Out:
#                        Calories  Total Fat (g)  Trans Fat (g)
# Flavour
# Bananas Foster              160            8.0            0.2
# World Class Chocolate       260           60.0            0.4

# %%
baskin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flavour            70 non-null     object
#  1   Calories           70 non-null     int64
#  2   Total Fat (g)      70 non-null     float64
#  3   Trans Fat (g)      70 non-null     float64
#  4   Carbohydrates (g)  70 non-null     int64
#  5   Sugars (g)         70 non-null     int64
#  6   Protein (g)        70 non-null     float64
#  7   Sugar Alcohol (g)  3 non-null      float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 4.5+ KB

# %%
bigmac=pd.read_csv('bigmac_index.csv', parse_dates=['date'])
bigmac
# Out:
#           date iso_a3 currency_code                  name  local_price  \
# 0   2011-07-01    ARG           ARS             Argentina        20.00
# 1   2011-07-01    AUS           AUD             Australia         4.56
# 2   2011-07-01    BRA           BRL                Brazil         9.50
# 3   2011-07-01    GBR           GBP               Britain         2.39
# 4   2011-07-01    CAN           CAD                Canada         4.73
# ..         ...    ...           ...                   ...          ...
# 752 2021-01-01    UKR           UAH               Ukraine        62.00
# 753 2021-01-01    ARE           AED  United Arab Emirates        14.75
# 754 2021-01-01    USA           USD         United States         5.66
# 755 2021-01-01    URY           UYU               Uruguay       204.00
# 756 2021-01-01    VNM           VND               Vietnam     66000.00
#
#         dollar_ex  dollar_price  GDP_dollar  adj_price      USD      EUR  \
# ...

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           757 non-null    datetime64[ns]
#  1   iso_a3         757 non-null    object
#  2   currency_code  757 non-null    object
#  3   name           757 non-null    object
#  4   local_price    757 non-null    float64
#  5   dollar_ex      757 non-null    float64
#  6   dollar_price   757 non-null    float64
#  7   GDP_dollar     757 non-null    float64
#  8   adj_price      757 non-null    float64
#  9   USD            757 non-null    float64
#  10  EUR            757 non-null    float64
#  11  GBP            757 non-null    float64
#  12  JPY            757 non-null    float64
#  13  CNY            757 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(3)
# memory usage: 82.9+ KB

# %%
bigmac['date'].dt.month
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 752    1
# 753    1
# 754    1
# 755    1
# 756    1
# Name: date, Length: 757, dtype: int64

# %%
bigmac['date'].dt.year
# Out:
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
#        ...
# 752    2021
# 753    2021
# 754    2021
# 755    2021
# 756    2021
# Name: date, Length: 757, dtype: int64

# %%
bigmac['date'].dt.day
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 752    1
# 753    1
# 754    1
# 755    1
# 756    1
# Name: date, Length: 757, dtype: int64

# %%
bigmac['date'].dt.quarter
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 752    1
# 753    1
# 754    1
# 755    1
# 756    1
# Name: date, Length: 757, dtype: int64

# %% [markdown]
# ---
# # read_html

# %%
ig=pd.read_html('https://en.wikipedia.org/wiki/List_of_most-followed_Instagram_accounts', match='Owner')
ig
# Out:
# [    Rank             Username                  Owner  Followers[2](millions)  \
#  0      1           @instagram              Instagram                     384
#  1      2           @cristiano      Cristiano Ronaldo                     257
#  2      3        @arianagrande          Ariana Grande                     218
#  3      4             @therock         Dwayne Johnson                     214
#  4      5         @kyliejenner           Kylie Jenner                     212
#  5      6         @selenagomez           Selena Gomez                     206
#  6      7       @kimkardashian         Kim Kardashian                     201
#  7      8            @leomessi           Lionel Messi                     180
#  8      9             @beyonce                Beyoncé                     162
#  9     10        @justinbieber          Justin Bieber                     160
#  10    11              @natgeo    National Geographic                     150
# ...

# %%
# read_html -> list(DataFrame)

# %%
type(ig)
# Out:
# list

# %%
len(ig)
# Out:
# 1

# %%
ig[0]
# Out:
#     Rank             Username                  Owner  Followers[2](millions)  \
# 0      1           @instagram              Instagram                     384
# 1      2           @cristiano      Cristiano Ronaldo                     257
# 2      3        @arianagrande          Ariana Grande                     218
# 3      4             @therock         Dwayne Johnson                     214
# 4      5         @kyliejenner           Kylie Jenner                     212
# 5      6         @selenagomez           Selena Gomez                     206
# 6      7       @kimkardashian         Kim Kardashian                     201
# 7      8            @leomessi           Lionel Messi                     180
# 8      9             @beyonce                Beyoncé                     162
# 9     10        @justinbieber          Justin Bieber                     160
# 10    11              @natgeo    National Geographic                     150
# ...

# %%
type(ig[0])
# Out:
# pandas.core.frame.DataFrame

# %%
ig=ig[0]
ig
# Out:
#     Rank             Username                  Owner  Followers[2](millions)  \
# 0      1           @instagram              Instagram                     384
# 1      2           @cristiano      Cristiano Ronaldo                     257
# 2      3        @arianagrande          Ariana Grande                     218
# 3      4             @therock         Dwayne Johnson                     214
# 4      5         @kyliejenner           Kylie Jenner                     212
# 5      6         @selenagomez           Selena Gomez                     206
# 6      7       @kimkardashian         Kim Kardashian                     201
# 7      8            @leomessi           Lionel Messi                     180
# 8      9             @beyonce                Beyoncé                     162
# 9     10        @justinbieber          Justin Bieber                     160
# 10    11              @natgeo    National Geographic                     150
# ...

# %%
ig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    50 non-null     int64
#  1   Username                50 non-null     object
#  2   Owner                   50 non-null     object
#  3   Followers[2](millions)  50 non-null     int64
#  4   Profession/Activity     50 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.1+ KB

# %% [markdown]
# ---
# SET index

# %%
dts=pd.read_html('https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&language=th&country=TH', match='หลักทรัพย์')
dts
# Out:
# [     ดัชนี   ล่าสุด  เปลี่ยนแปลง  %เปลี่ยนแปลง   สูงสุด   ต่ำสุด  \
#  0      SET  1510.00        -2.83         -0.19  1515.32  1508.61
#  1    SET50   947.08        -3.94         -0.41   951.58   945.88
#  2   SET100  2128.63        -5.82         -0.27  2137.65  2126.12
#  3     sSET   738.61         2.51          0.34   740.05   738.11
#  4  SETCLMV   994.43         6.84          0.69   995.25   990.04
#  5    SETHD  1072.56        -2.00         -0.19  1077.17  1070.64
#  6  SETTHSI   960.50        -2.73         -0.28   964.60   959.09
#  7    SETWB   910.30         3.22          0.35   912.18   906.88
#  8      mai   356.81         2.13          0.60   357.33   355.70
#
#     ปริมาณ('000 หุ้น)  มูลค่า(ล้านบาท)
#  0            3596181         12087.57
#  1             209390          6792.70
#  2             429187          9304.20
#  3             216527           828.27
#  4             202468          3983.32
#  5              60804          2382.63
# ...

# %%
len(dts)
# Out:
# 2

# %%
dts[1]
# Out:
#    หลักทรัพย์  เครื่องหมาย    เปิด  สูงสุด  ต่ำสุด  ล่าสุด เปลี่ยนแปลง  \
# 0      ADVANC          NaN  176.00  177.00  176.00  177.00       +0.50
# 1         AOT          NaN   60.25   60.75   60.00   60.25           -
# 2         AWC          NaN    4.64    4.72    4.62    4.70       +0.06
# 3         BAM          NaN   21.50   21.50   21.40   21.40       +0.10
# 4         BBL          NaN  121.50  121.50  120.00  121.00       -0.50
# 5        BDMS          NaN   21.60   21.70   21.50   21.60       +0.10
# 6         BEM          NaN    8.20    8.25    8.20    8.25       +0.05
# 7       BGRIM          NaN   52.25   52.50   51.75   52.25       +0.25
# 8          BH          NaN  128.00  128.00  126.00  126.00       -2.00
# 9         BJC          NaN   35.25   35.50   35.00   35.50       +0.25
# 10        BTS          NaN    9.70    9.80    9.70    9.80       +0.10
# 11        CBG          NaN  146.00  147.00  145.00  147.00       +2.50
# ...

# %%
dts[1].to_csv('set50.csv', index=False)

# %%
dts[1].to_excel('set50.xlsx', index=False)

# %%
d_set=pd.read_csv('set50.csv')
d_set
# Out:
#    หลักทรัพย์  เครื่องหมาย    เปิด  สูงสุด  ต่ำสุด  ล่าสุด เปลี่ยนแปลง  \
# 0      ADVANC          NaN  176.00  177.00  176.00  177.00       +0.50
# 1         AOT          NaN   60.25   60.75   60.00   60.25           -
# 2         AWC          NaN    4.64    4.72    4.62    4.70       +0.06
# 3         BAM          NaN   21.50   21.50   21.40   21.40       +0.10
# 4         BBL          NaN  121.50  121.50  120.00  121.00       -0.50
# 5        BDMS          NaN   21.60   21.70   21.50   21.60       +0.10
# 6         BEM          NaN    8.20    8.25    8.20    8.25       +0.05
# 7       BGRIM          NaN   52.25   52.50   51.75   52.25       +0.25
# 8          BH          NaN  128.00  128.00  126.00  126.00       -2.00
# 9         BJC          NaN   35.25   35.50   35.00   35.50       +0.25
# 10        BTS          NaN    9.70    9.80    9.70    9.80       +0.10
# 11        CBG          NaN  146.00  147.00  145.00  147.00       +2.50
# ...

# %%
d_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   หลักทรัพย์        50 non-null     object
#  1   เครื่องหมาย       0 non-null      float64
#  2   เปิด              50 non-null     float64
#  3   สูงสุด            50 non-null     float64
#  4   ต่ำสุด            50 non-null     float64
#  5   ล่าสุด            50 non-null     float64
#  6   เปลี่ยนแปลง       50 non-null     object
#  7   %เปลี่ยนแปลง      50 non-null     object
#  8   เสนอซื้อ          50 non-null     float64
#  9   เสนอขาย           50 non-null     float64
#  10  ปริมาณ(หุ้น)      50 non-null     int64
#  11  มูลค่า('000 บาท)  50 non-null     float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 4.8+ KB

# %%
d_set['เปลี่ยนแปลง']=pd.to_numeric(d_set['เปลี่ยนแปลง'], errors='coerce')

# %%
d_set['%เปลี่ยนแปลง']=pd.to_numeric(d_set['%เปลี่ยนแปลง'], errors='coerce')

# %%
d_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   หลักทรัพย์        50 non-null     object
#  1   เครื่องหมาย       0 non-null      float64
#  2   เปิด              50 non-null     float64
#  3   สูงสุด            50 non-null     float64
#  4   ต่ำสุด            50 non-null     float64
#  5   ล่าสุด            50 non-null     float64
#  6   เปลี่ยนแปลง       37 non-null     float64
#  7   %เปลี่ยนแปลง      37 non-null     float64
#  8   เสนอซื้อ          50 non-null     float64
#  9   เสนอขาย           50 non-null     float64
#  10  ปริมาณ(หุ้น)      50 non-null     int64
#  11  มูลค่า('000 บาท)  50 non-null     float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 4.8+ KB

# %%
d_set
# Out:
#    หลักทรัพย์  เครื่องหมาย    เปิด  สูงสุด  ต่ำสุด  ล่าสุด  เปลี่ยนแปลง  \
# 0      ADVANC          NaN  176.00  177.00  176.00  177.00         0.50
# 1         AOT          NaN   60.25   60.75   60.00   60.25          NaN
# 2         AWC          NaN    4.64    4.72    4.62    4.70         0.06
# 3         BAM          NaN   21.50   21.50   21.40   21.40         0.10
# 4         BBL          NaN  121.50  121.50  120.00  121.00        -0.50
# 5        BDMS          NaN   21.60   21.70   21.50   21.60         0.10
# 6         BEM          NaN    8.20    8.25    8.20    8.25         0.05
# 7       BGRIM          NaN   52.25   52.50   51.75   52.25         0.25
# 8          BH          NaN  128.00  128.00  126.00  126.00        -2.00
# 9         BJC          NaN   35.25   35.50   35.00   35.50         0.25
# 10        BTS          NaN    9.70    9.80    9.70    9.80         0.10
# 11        CBG          NaN  146.00  147.00  145.00  147.00         2.50
# ...

# %%
d_set.to_csv('set50.csv', index=False)

d_set.to_excel('set50.xlsx', index=False)

# %% [markdown]
# ---
# # Missing values

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/msleep.csv', index_col='name')
df
# Out:
#                                  genus   vore         order  conservation  \
# name
# Cheetah                       Acinonyx  carni     Carnivora            lc
# Owl monkey                       Aotus   omni      Primates           NaN
# Mountain beaver             Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# Cow                                Bos  herbi  Artiodactyla  domesticated
# ...                                ...    ...           ...           ...
# Tree shrew                      Tupaia   omni    Scandentia           NaN
# Bottle-nosed dolphin          Tursiops  carni       Cetacea           NaN
# Genet                          Genetta  carni     Carnivora           NaN
# Arctic fox                      Vulpes  carni     Carnivora           NaN
# Red fox                         Vulpes  carni     Carnivora           NaN
#
#                             sleep_total  sleep_rem  sleep_cycle  awake  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          83 non-null     object
#  1   genus         83 non-null     object
#  2   vore          76 non-null     object
#  3   order         83 non-null     object
#  4   conservation  54 non-null     object
#  5   sleep_total   83 non-null     float64
#  6   sleep_rem     61 non-null     float64
#  7   sleep_cycle   32 non-null     float64
#  8   awake         83 non-null     float64
#  9   brainwt       56 non-null     float64
#  10  bodywt        83 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.3+ KB

# %%
df.isna()
# Out:
#      name  genus   vore  order  conservation  sleep_total  sleep_rem  \
# 0   False  False  False  False         False        False       True
# 1   False  False  False  False          True        False      False
# 2   False  False  False  False         False        False      False
# 3   False  False  False  False         False        False      False
# 4   False  False  False  False         False        False      False
# ..    ...    ...    ...    ...           ...          ...        ...
# 78  False  False  False  False          True        False      False
# 79  False  False  False  False          True        False       True
# 80  False  False  False  False          True        False      False
# 81  False  False  False  False          True        False       True
# 82  False  False  False  False          True        False      False
#
#     sleep_cycle  awake  brainwt  bodywt
# 0          True  False     True   False
# 1          True  False    False   False
# ...

# %%
df.isna().sum()/len(df)
# Out:
# name            0.000000
# genus           0.000000
# vore            0.084337
# order           0.000000
# conservation    0.349398
# sleep_total     0.000000
# sleep_rem       0.265060
# sleep_cycle     0.614458
# awake           0.000000
# brainwt         0.325301
# bodywt          0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          83 non-null     object
#  1   genus         83 non-null     object
#  2   vore          76 non-null     object
#  3   order         83 non-null     object
#  4   conservation  54 non-null     object
#  5   sleep_total   83 non-null     float64
#  6   sleep_rem     61 non-null     float64
#  7   sleep_cycle   32 non-null     float64
#  8   awake         83 non-null     float64
#  9   brainwt       56 non-null     float64
#  10  bodywt        83 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.3+ KB

# %%
df['brainwt'].mean()
# Out:
# 0.28158142857142854

# %%
df['brainwt']
# Out:
# 0         NaN
# 1     0.01550
# 2         NaN
# 3     0.00029
# 4     0.42300
#        ...
# 78    0.00250
# 79        NaN
# 80    0.01750
# 81    0.04450
# 82    0.05040
# Name: brainwt, Length: 83, dtype: float64

# %%
df['brain_body_wt']=df['brainwt']/df['bodywt']

# %%
df
# Out:
#                                  genus   vore         order  conservation  \
# name
# Cheetah                       Acinonyx  carni     Carnivora            lc
# Owl monkey                       Aotus   omni      Primates           NaN
# Mountain beaver             Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# Cow                                Bos  herbi  Artiodactyla  domesticated
# ...                                ...    ...           ...           ...
# Tree shrew                      Tupaia   omni    Scandentia           NaN
# Bottle-nosed dolphin          Tursiops  carni       Cetacea           NaN
# Genet                          Genetta  carni     Carnivora           NaN
# Arctic fox                      Vulpes  carni     Carnivora           NaN
# Red fox                         Vulpes  carni     Carnivora           NaN
#
#                             sleep_total  sleep_rem  sleep_cycle  awake  \
# ...

# %%
df['brain_body_wt'].sort_values(ascending=False)
# Out:
# name
# Thirteen-lined ground squirrel    0.039604
# Owl monkey                        0.032292
# Lesser short-tailed shrew         0.028000
# Squirrel monkey                   0.026918
# Macaque                           0.026324
#                                     ...
# Potoroo                                NaN
# African striped mouse                  NaN
# Golden-mantled ground squirrel         NaN
# Eastern american chipmunk              NaN
# Bottle-nosed dolphin                   NaN
# Name: brain_body_wt, Length: 83, dtype: float64

# %%
df.index
# Out:
# Index(['Cheetah', 'Owl monkey', 'Mountain beaver',
#        'Greater short-tailed shrew', 'Cow', 'Three-toed sloth',
#        'Northern fur seal', 'Vesper mouse', 'Dog', 'Roe deer', 'Goat',
#        'Guinea pig', 'Grivet', 'Chinchilla', 'Star-nosed mole',
#        'African giant pouched rat', 'Lesser short-tailed shrew',
#        'Long-nosed armadillo', 'Tree hyrax', 'North American Opossum',
#        'Asian elephant', 'Big brown bat', 'Horse', 'Donkey',
#        'European hedgehog', 'Patas monkey', 'Western american chipmunk',
#        'Domestic cat', 'Galago', 'Giraffe', 'Pilot whale', 'Gray seal',
#        'Gray hyrax', 'Human', 'Mongoose lemur', 'African elephant',
#        'Thick-tailed opposum', 'Macaque', 'Mongolian gerbil', 'Golden hamster',
#        'Vole ', 'House mouse', 'Little brown bat', 'Round-tailed muskrat',
#        'Slow loris', 'Degu', 'Northern grasshopper mouse', 'Rabbit', 'Sheep',
#        'Chimpanzee', 'Tiger', 'Jaguar', 'Lion', 'Baboon', 'Desert hedgehog',
# ...

# %%
df.index.str.contains('human')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %% [markdown]
# # impute/imputing value
# remove
# mean/mode/median
# regression

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df.describe() # numerical data/columns
# Out:
#        sleep_total  sleep_rem  sleep_cycle      awake    brainwt       bodywt  \
# count    83.000000  61.000000    32.000000  83.000000  56.000000    83.000000
# mean     10.433735   1.875410     0.439583  13.567470   0.281581   166.136349
# std       4.450357   1.298288     0.358680   4.452085   0.976414   786.839732
# min       1.900000   0.100000     0.116667   4.100000   0.000140     0.005000
# 25%       7.850000   0.900000     0.183333  10.250000   0.002900     0.174000
# 50%      10.100000   1.500000     0.333333  13.900000   0.012400     1.670000
# 75%      13.750000   2.400000     0.579167  16.150000   0.125500    41.750000
# max      19.900000   6.600000     1.500000  22.100000   5.712000  6654.000000
#
#        brain_body_wt
# count      56.000000
# mean        0.010356
# std         0.009251
# min         0.000705
# 25%         0.003794
# 50%         0.006956
# 75%         0.015244
# max         0.039604

# %%
df.corr() # Pearson correlation
# Out:
#                sleep_total  sleep_rem  sleep_cycle     awake   brainwt  \
# sleep_total       1.000000   0.751755    -0.473713 -0.999999 -0.360487
# sleep_rem         0.751755   1.000000    -0.338123 -0.751771 -0.221335
# sleep_cycle      -0.473713  -0.338123     1.000000  0.473713  0.851620
# awake            -0.999999  -0.751771     0.473713  1.000000  0.360487
# brainwt          -0.360487  -0.221335     0.851620  0.360487  1.000000
# bodywt           -0.312011  -0.327651     0.417803  0.311980  0.933782
# brain_body_wt     0.318011   0.046468    -0.145105 -0.318011 -0.202911
#
#                  bodywt  brain_body_wt
# sleep_total   -0.312011       0.318011
# sleep_rem     -0.327651       0.046468
# sleep_cycle    0.417803      -0.145105
# awake          0.311980      -0.318011
# brainwt        0.933782      -0.202911
# bodywt         1.000000      -0.211831
# brain_body_wt -0.211831       1.000000

# %% [markdown]
# # visualizing
# 1. pandas
# 1. matplotlib
# 1. seaborn

# %%
df.hist(figsize=(10, 7)) # histogram
# Out:
# array([[<AxesSubplot:title={'center':'sleep_total'}>,
#         <AxesSubplot:title={'center':'sleep_rem'}>,
#         <AxesSubplot:title={'center':'sleep_cycle'}>],
#        [<AxesSubplot:title={'center':'awake'}>,
#         <AxesSubplot:title={'center':'brainwt'}>,
#         <AxesSubplot:title={'center':'bodywt'}>],
#        [<AxesSubplot:title={'center':'brain_body_wt'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df['sleep_total'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['brainwt'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(y='brainwt', x='bodywt')
# Out:
# <AxesSubplot:xlabel='bodywt', ylabel='brainwt'>
