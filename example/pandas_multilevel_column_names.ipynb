# %% [markdown]
# # Multilevel Column Names

# %%
import pandas as pd
from pandas_datareader import data
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
print(f"pandas  version = {pd.__version__}")
print(f"seaborn version = {sns.__version__}")
# Out:
# pandas  version = 1.2.0
# seaborn version = 0.11.1

# %% [markdown]
# ## single-level column name

# %%
url='https://github.com/prasertcbs/tutorial/raw/master/mpg.csv'
dat=pd.read_csv(url)
dat.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
dat.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# # read multilevel columns from CSV

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/GlobalFirePower/GlobalFirePower_multiindex.csv',
              header=[0, 1])
df
# Out:
#                  Country Data                   Manpower                     \
#                       Country ISO3 Rank Total Population Manpower Available
# 0               United States  USA    1        323995528          145215000
# 1                      Russia  RUS    2        142355415           70000000
# 2                       China  CHN    3       1373541278          750000000
# 3                       India  IND    4       1266883598          616000000
# 4                      France  FRA    5         66836154           30000000
# ..                        ...  ...  ...              ...                ...
# 128  Central African Republic  CAR  129          5507257            2300000
# 129                Mauritania  MAU  130          3677293            1523335
# 130              Sierra Leone  SIE  131          6018888            1402400
# 131                  Suriname  SUR  132           585824             131700
# 132                    Bhutan  BUT  133           750125             175000
#
#                                                                     \
#     Fit-for-Service Reaching Military Age Total Military Personnel
# 0         120025000               4220000                  2363675
# 1          47000000               1355000                  3371027
# 2         619000000              19550000                  3712500
# 3         489600000              22900000                  4207250
# 4          23750000                775000                   387635
# ..              ...                   ...                      ...
# 128         1320000                110000                     5825
# 129         1061515                 72942                    20870
# 130          835830                 32848                    10750
# 131           77100                  3030                     2270
# 132          104300                  4100                     7500
#
#                                         ...             Logistics  \
#     Active Personnel Reserve Personnel  ... Railway Coverage (km)
# 0            1373650            990025  ...                224792
# 1             798527           2572500  ...                 87157
# 2            2260000           1452500  ...                 86000
# 3            1362500           2844750  ...                 63974
# 4             204000            183635  ...                 29640
# ..               ...               ...  ...                   ...
# 128             5825                 0  ...                     0
# 129            15870              5000  ...                   728
# 130            10750                 0  ...                     0
# 131             2170               100  ...                     0
# 132             7500                 0  ...                     0
#
#                                 Finance                                        \
#     Serivecable Airports Defense Budget External Debt Foreign Exchange / Gold
# 0                  13513         587800      17910000                  117600
# 1                   1218          44600        514800                  365500
# 2                    507         161700        983500                 3092000
# 3                    346          51000        507000                  359100
# 4                    464          35000       5360000                  138200
# ..                   ...            ...           ...                     ...
# 128                   39             18           686                    4128
# 129                   30             39       3585000                    1186
# 130                    8             13          1561                    2332
# 131                   55             67          1439                     393
# 132                    2             10          2261                      15
#
#                                         Geography                 \
#     Purchasing Power Parity Square Land Area (km) Coastline (km)
# 0                  18560000               9826675          19924
# 1                   3745000              17098242          37653
# 2                  21270000               9596961          14500
# 3                   8721000               3287263           7000
# 4                   2737000                643801           4853
# ..                      ...                   ...            ...
# 128                    3206                622984     Landlocked
# 129                   16710               1030700            754
# 130                   10640                 71740            402
# 131                    8547                163820            386
# 132                    6432                 38394     Landlocked
#
#
#     Shared Borders (km)    Waterways (km)
# 0                 12048             41009
# 1                 22408            102000
# 2                 22457            110000
# 3                 13888             14500
# 4                  4072              8501
# ..                  ...               ...
# 128                5920              2800
# 129                5002  Minimum not met.
# 130                1093               800
# 131                1907              1200
# 132                1136  Minimum not met.
#
# [133 rows x 47 columns]

# %%
df.columns
# Out:
# MultiIndex([(     'Country Data',                   'Country'),
#             (     'Country Data',                      'ISO3'),
#             (     'Country Data',                      'Rank'),
#             (         'Manpower',          'Total Population'),
#             (         'Manpower',        'Manpower Available'),
#             (         'Manpower',           'Fit-for-Service'),
#             (         'Manpower',     'Reaching Military Age'),
#             (         'Manpower',  'Total Military Personnel'),
#             (         'Manpower',          'Active Personnel'),
#             (         'Manpower',         'Reserve Personnel'),
#             (        'Air Power',   'Total Aircraft Strength'),
#             (        'Air Power',          'Fighter Aircraft'),
#             (        'Air Power',           'Attack Aircraft'),
#             (        'Air Power',        'Transport Aircraft'),
#             (        'Air Power',          'Trainer Aircraft'),
#             (        'Air Power', 'Total Helicopter Strength'),
#             (        'Air Power',        'Attack Helicopters'),
#             (    'Army Strength',              'Combat Tanks'),
#             (    'Army Strength', 'Armored Fighting Vehicles'),
#             (    'Army Strength',  'Self-Propelled Artillery'),
#             (    'Army Strength',           'Towed Artillery'),
#             (    'Army Strength',         'Rocket Projectors'),
#             (    'Navy Strength',        'Total Naval Assets'),
#             (    'Navy Strength',         'Aircraft Carriers'),
#             (    'Navy Strength',                  'Frigates'),
#             (    'Navy Strength',                'Destroyers'),
#             (    'Navy Strength',                 'Corvettes'),
#             (    'Navy Strength',                'Submarines'),
#             (    'Navy Strength',              'Patrol Craft'),
#             (    'Navy Strength',      'Mine Warfare Vessels'),
#             ('Natural Resources',       'Production (bbl/dy)'),
#             ('Natural Resources',      'Consumption (bbl/dy)'),
#             ('Natural Resources',     'Proven Reserves (bbl)'),
#             (        'Logistics',               'Labor Force'),
#             (        'Logistics',  'Merchant Marine Strength'),
#             (        'Logistics',   'Major Ports / Terminals'),
#             (        'Logistics',     'Roadway Coverage (km)'),
#             (        'Logistics',     'Railway Coverage (km)'),
#             (        'Logistics',      'Serivecable Airports'),
#             (          'Finance',            'Defense Budget'),
#             (          'Finance',             'External Debt'),
#             (          'Finance',   'Foreign Exchange / Gold'),
#             (          'Finance',   'Purchasing Power Parity'),
#             (        'Geography',     'Square Land Area (km)'),
#             (        'Geography',            'Coastline (km)'),
#             (        'Geography',       'Shared Borders (km)'),
#             (        'Geography',            'Waterways (km)')],
#            )

# %%
df['Country Data']
# Out:
#                       Country ISO3  Rank
# 0               United States  USA     1
# 1                      Russia  RUS     2
# 2                       China  CHN     3
# 3                       India  IND     4
# 4                      France  FRA     5
# ..                        ...  ...   ...
# 128  Central African Republic  CAR   129
# 129                Mauritania  MAU   130
# 130              Sierra Leone  SIE   131
# 131                  Suriname  SUR   132
# 132                    Bhutan  BUT   133
#
# [133 rows x 3 columns]

# %%
df['Logistics']
# Out:
#      Labor Force  Merchant Marine Strength  Major Ports / Terminals  \
# 0      158600000                       393                       24
# 1       77410000                      1143                        7
# 2      805900000                      2030                       15
# 3      513700000                       340                        7
# 4       30480000                       162                       14
# ..           ...                       ...                      ...
# 128      2421000                         0                        2
# 129      1356000                         0                        2
# 130      2678000                       215                        3
# 131       154100                         0                        2
# 132       353000                         0                        0
#
#      Roadway Coverage (km)  Railway Coverage (km)  Serivecable Airports
# 0                  6586610                 224792                 13513
# 1                   982000                  87157                  1218
# 2                  3860800                  86000                   507
# 3                  3320410                  63974                   346
# 4                   951200                  29640                   464
# ..                     ...                    ...                   ...
# 128                  20278                      0                    39
# 129                  10628                    728                    30
# 130                  11300                      0                     8
# 131                   4304                      0                    55
# 132                  10578                      0                     2
#
# [133 rows x 6 columns]

# %%
df['Logistics']['Roadway Coverage (km)']
# Out:
# 0      6586610
# 1       982000
# 2      3860800
# 3      3320410
# 4       951200
#         ...
# 128      20278
# 129      10628
# 130      11300
# 131       4304
# 132      10578
# Name: Roadway Coverage (km), Length: 133, dtype: int64

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/GlobalFirePower/GlobalFirePower_multiindex.csv',
              header=[1])
df
# Out:
#                       Country ISO3  Rank  Total Population  \
# 0               United States  USA     1         323995528
# 1                      Russia  RUS     2         142355415
# 2                       China  CHN     3        1373541278
# 3                       India  IND     4        1266883598
# 4                      France  FRA     5          66836154
# ..                        ...  ...   ...               ...
# 128  Central African Republic  CAR   129           5507257
# 129                Mauritania  MAU   130           3677293
# 130              Sierra Leone  SIE   131           6018888
# 131                  Suriname  SUR   132            585824
# 132                    Bhutan  BUT   133            750125
#
#      Manpower Available  Fit-for-Service  Reaching Military Age  \
# 0             145215000        120025000                4220000
# 1              70000000         47000000                1355000
# 2             750000000        619000000               19550000
# 3             616000000        489600000               22900000
# 4              30000000         23750000                 775000
# ..                  ...              ...                    ...
# 128             2300000          1320000                 110000
# 129             1523335          1061515                  72942
# 130             1402400           835830                  32848
# 131              131700            77100                   3030
# 132              175000           104300                   4100
#
#      Total Military Personnel  Active Personnel  Reserve Personnel  ...  \
# 0                     2363675           1373650             990025  ...
# 1                     3371027            798527            2572500  ...
# 2                     3712500           2260000            1452500  ...
# 3                     4207250           1362500            2844750  ...
# 4                      387635            204000             183635  ...
# ..                        ...               ...                ...  ...
# 128                      5825              5825                  0  ...
# 129                     20870             15870               5000  ...
# 130                     10750             10750                  0  ...
# 131                      2270              2170                100  ...
# 132                      7500              7500                  0  ...
#
#      Railway Coverage (km)  Serivecable Airports  Defense Budget  \
# 0                   224792                 13513          587800
# 1                    87157                  1218           44600
# 2                    86000                   507          161700
# 3                    63974                   346           51000
# 4                    29640                   464           35000
# ..                     ...                   ...             ...
# 128                      0                    39              18
# 129                    728                    30              39
# 130                      0                     8              13
# 131                      0                    55              67
# 132                      0                     2              10
#
#      External Debt  Foreign Exchange / Gold  Purchasing Power Parity  \
# 0         17910000                   117600                 18560000
# 1           514800                   365500                  3745000
# 2           983500                  3092000                 21270000
# 3           507000                   359100                  8721000
# 4          5360000                   138200                  2737000
# ..             ...                      ...                      ...
# 128            686                     4128                     3206
# 129        3585000                     1186                    16710
# 130           1561                     2332                    10640
# 131           1439                      393                     8547
# 132           2261                       15                     6432
#
#      Square Land Area (km)  Coastline (km)  Shared Borders (km)  \
# 0                  9826675           19924                12048
# 1                 17098242           37653                22408
# 2                  9596961           14500                22457
# 3                  3287263            7000                13888
# 4                   643801            4853                 4072
# ..                     ...             ...                  ...
# 128                 622984      Landlocked                 5920
# 129                1030700             754                 5002
# 130                  71740             402                 1093
# 131                 163820             386                 1907
# 132                  38394      Landlocked                 1136
#
#        Waterways (km)
# 0               41009
# 1              102000
# 2              110000
# 3               14500
# 4                8501
# ..                ...
# 128              2800
# 129  Minimum not met.
# 130               800
# 131              1200
# 132  Minimum not met.
#
# [133 rows x 47 columns]

# %% [markdown]
# ## get stocks (multilevel column names)

# %%
stocks=['fb', 'aapl', 'msft']
df = data.DataReader(stocks, data_source="yahoo",
                     start="2019-01-02")
df.head()
# Out:
# Attributes        High                                 Low              \
# Symbols           aapl          fb        msft        aapl          fb
# Date
# 2019-01-02  158.850006  137.509995  101.750000  154.229996  128.559998
# 2019-01-03  145.720001  137.169998  100.190002  142.000000  131.119995
# 2019-01-04  148.550003  138.000000  102.510002  143.800003  133.750000
# 2019-01-07  148.830002  138.869995  103.269997  145.899994  135.910004
# 2019-01-08  151.820007  143.139999  103.970001  148.520004  139.539993
#
# Attributes                    Open                               Close  \
# Symbols           msft        aapl          fb        msft        aapl
# Date
# 2019-01-02   98.940002  154.889999  128.990005   99.550003  157.919998
# 2019-01-03   97.199997  143.979996  134.690002  100.099998  142.190002
# 2019-01-04   98.930000  144.529999  134.009995   99.720001  148.259995
# 2019-01-07  100.980003  148.699997  137.559998  101.639999  147.929993
# 2019-01-08  101.709999  149.559998  139.889999  103.040001  150.750000
#
# Attributes                            Volume                       Adj Close  \
# Symbols             fb        msft      aapl        fb      msft        aapl
# Date
# 2019-01-02  135.679993  101.120003  37039700  28146200  35329300  157.919998
# 2019-01-03  131.740005   97.400002  91312200  22717900  42579100  142.190002
# 2019-01-04  137.949997  101.930000  58607100  29002100  44060600  148.259995
# 2019-01-07  138.050003  102.059998  54777800  20089300  35656100  147.929993
# 2019-01-08  142.529999  102.800003  41025300  26263800  31514400  150.750000
#
# Attributes
# Symbols             fb        msft
# Date
# 2019-01-02  135.679993  101.120003
# 2019-01-03  131.740005   97.400002
# 2019-01-04  137.949997  101.930000
# 2019-01-07  138.050003  102.059998
# 2019-01-08  142.529999  102.800003

# %%
# stocks=['scc.bk', 'bh.bk']
# df = data.DataReader(stocks, data_source="yahoo",
#                      start="2019-01-02")
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8 entries, 2019-01-02 to 2019-01-11
# Data columns (total 18 columns):
# (High, aapl)         8 non-null float64
# (High, fb)           8 non-null float64
# (High, msft)         8 non-null float64
# (Low, aapl)          8 non-null float64
# (Low, fb)            8 non-null float64
# (Low, msft)          8 non-null float64
# (Open, aapl)         8 non-null float64
# (Open, fb)           8 non-null float64
# (Open, msft)         8 non-null float64
# (Close, aapl)        8 non-null float64
# (Close, fb)          8 non-null float64
# (Close, msft)        8 non-null float64
# (Volume, aapl)       8 non-null int64
# (Volume, fb)         8 non-null int64
# (Volume, msft)       8 non-null int64
# (Adj Close, aapl)    8 non-null float64
# (Adj Close, fb)      8 non-null float64
# (Adj Close, msft)    8 non-null float64
# dtypes: float64(15), int64(3)
# memory usage: 1.2 KB

# %%
df.head()
# Out:
# Attributes        High                                 Low              \
# Symbols           aapl          fb        msft        aapl          fb
# Date
# 2019-01-02  158.850006  137.509995  101.750000  154.229996  128.559998
# 2019-01-03  145.720001  137.169998  100.190002  142.000000  131.119995
# 2019-01-04  148.550003  138.000000  102.510002  143.800003  133.750000
# 2019-01-07  148.830002  138.869995  103.269997  145.899994  135.910004
# 2019-01-08  151.820007  143.139999  103.970001  148.520004  139.539993
#
# Attributes                    Open                               Close  \
# Symbols           msft        aapl          fb        msft        aapl
# Date
# 2019-01-02   98.940002  154.889999  128.990005   99.550003  157.919998
# 2019-01-03   97.199997  143.979996  134.690002  100.099998  142.190002
# 2019-01-04   98.930000  144.529999  134.009995   99.720001  148.259995
# 2019-01-07  100.980003  148.699997  137.559998  101.639999  147.929993
# 2019-01-08  101.709999  149.559998  139.889999  103.040001  150.750000
#
# Attributes                            Volume                       Adj Close  \
# Symbols             fb        msft      aapl        fb      msft        aapl
# Date
# 2019-01-02  135.679993  101.120003  37039700  28146200  35329300  157.919998
# 2019-01-03  131.740005   97.400002  91312200  22717900  42579100  142.190002
# 2019-01-04  137.949997  101.930000  58607100  29002100  44060600  148.259995
# 2019-01-07  138.050003  102.059998  54777800  20089300  35656100  147.929993
# 2019-01-08  142.529999  102.800003  41025300  26263800  31514400  150.750000
#
# Attributes
# Symbols             fb        msft
# Date
# 2019-01-02  135.679993  101.120003
# 2019-01-03  131.740005   97.400002
# 2019-01-04  137.949997  101.930000
# 2019-01-07  138.050003  102.059998
# 2019-01-08  142.529999  102.800003

# %%
df.columns
# Out:
# MultiIndex(levels=[['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], ['aapl', 'fb', 'msft']],
#            labels=[[0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5], [0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2]],
#            names=['Attributes', 'Symbols'])

# %%
df['High']
# Out:
# Symbols           aapl          fb        msft
# Date
# 2019-01-02  158.850006  137.509995  101.750000
# 2019-01-03  145.720001  137.169998  100.190002
# 2019-01-04  148.550003  138.000000  102.510002
# 2019-01-07  148.830002  138.869995  103.269997
# 2019-01-08  151.820007  143.139999  103.970001
# 2019-01-09  154.529999  144.699997  104.879997
# 2019-01-10  153.970001  144.559998  103.750000
# 2019-01-11  153.699997  145.360001  103.440002

# %%
df['High']['fb']
# Out:
# Date
# 2019-01-02    137.509995
# 2019-01-03    137.169998
# 2019-01-04    138.000000
# 2019-01-07    138.869995
# 2019-01-08    143.139999
# 2019-01-09    144.699997
# 2019-01-10    144.559998
# 2019-01-11    145.360001
# Name: fb, dtype: float64

# %%
df.loc['2019-01-08':]
# Out:
# Attributes        High                                 Low              \
# Symbols           aapl          fb        msft        aapl          fb
# Date
# 2019-01-08  151.820007  143.139999  103.970001  148.520004  139.539993
# 2019-01-09  154.529999  144.699997  104.879997  149.630005  141.270004
# 2019-01-10  153.970001  144.559998  103.750000  150.860001  140.839996
# 2019-01-11  153.699997  145.360001  103.440002  151.509995  142.570007
#
# Attributes                    Open                               Close  \
# Symbols           msft        aapl          fb        msft        aapl
# Date
# 2019-01-08  101.709999  149.559998  139.889999  103.040001  150.750000
# 2019-01-09  103.239998  151.289993  142.949997  103.860001  153.309998
# 2019-01-10  102.379997  152.500000  143.080002  103.220001  153.800003
# 2019-01-11  101.639999  152.880005  143.149994  103.190002  152.289993
#
# Attributes                            Volume                       Adj Close  \
# Symbols             fb        msft      aapl        fb      msft        aapl
# Date
# 2019-01-08  142.529999  102.800003  41025300  26263800  31514400  150.750000
# 2019-01-09  144.229996  104.269997  45099100  22205900  32280800  153.309998
# 2019-01-10  144.199997  103.599998  35780700  16125000  30067600  153.800003
# 2019-01-11  143.800003  102.800003  26976300  12785900  28242100  152.289993
#
# Attributes
# Symbols             fb        msft
# Date
# 2019-01-08  142.529999  102.800003
# 2019-01-09  144.229996  104.269997
# 2019-01-10  144.199997  103.599998
# 2019-01-11  143.800003  102.800003

# %%
df.loc['2019-01-08':, 'Open']
# Out:
# Symbols           aapl          fb        msft
# Date
# 2019-01-08  149.559998  139.889999  103.040001
# 2019-01-09  151.289993  142.949997  103.860001
# 2019-01-10  152.500000  143.080002  103.220001
# 2019-01-11  152.880005  143.149994  103.190002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8 entries, 2019-01-02 to 2019-01-11
# Data columns (total 18 columns):
# (High, aapl)         8 non-null float64
# (High, fb)           8 non-null float64
# (High, msft)         8 non-null float64
# (Low, aapl)          8 non-null float64
# (Low, fb)            8 non-null float64
# (Low, msft)          8 non-null float64
# (Open, aapl)         8 non-null float64
# (Open, fb)           8 non-null float64
# (Open, msft)         8 non-null float64
# (Close, aapl)        8 non-null float64
# (Close, fb)          8 non-null float64
# (Close, msft)        8 non-null float64
# (Volume, aapl)       8 non-null int64
# (Volume, fb)         8 non-null int64
# (Volume, msft)       8 non-null int64
# (Adj Close, aapl)    8 non-null float64
# (Adj Close, fb)      8 non-null float64
# (Adj Close, msft)    8 non-null float64
# dtypes: float64(15), int64(3)
# memory usage: 1.5 KB

# %%
df.loc['2019-01-08':, ('Open', 'aapl')]
# Out:
# Date
# 2019-01-08    149.559998
# 2019-01-09    151.289993
# 2019-01-10    152.500000
# 2019-01-11    152.880005
# Name: (Open, aapl), dtype: float64

# %%
df.loc['2019-01-08':'2019-01-10', ('Open', 'aapl')]
# Out:
# Date
# 2019-01-08    149.559998
# 2019-01-09    151.289993
# 2019-01-10    152.500000
# Name: (Open, aapl), dtype: float64

# %%
df.loc['2019-01-08':'2019-01-10', ('Open', ['aapl', 'fb'])]
# Out:
# Attributes        Open
# Symbols           aapl          fb
# Date
# 2019-01-08  149.559998  139.889999
# 2019-01-09  151.289993  142.949997
# 2019-01-10  152.500000  143.080002

# %%
df.loc['2019-01-08':'2019-01-10', (['Open', 'Close'], ['aapl', 'fb'])]
# Out:
# Attributes        Open                   Close
# Symbols           aapl          fb        aapl          fb
# Date
# 2019-01-08  149.559998  139.889999  150.750000  142.529999
# 2019-01-09  151.289993  142.949997  153.309998  144.229996
# 2019-01-10  152.500000  143.080002  153.800003  144.199997

# %%
df.to_csv('mlevel_col_names.csv')
df.to_excel('mlevel_col_names.xlsx')

# %% [markdown]
# ## stack data frame

# %%
df.stack()
# Out:
# Attributes                High         Low        Open       Close    Volume  \
# Date       Symbols
# 2019-01-02 aapl     158.850006  154.229996  154.889999  157.919998  37039700
#            fb       137.509995  128.559998  128.990005  135.679993  28146200
#            msft     101.750000   98.940002   99.550003  101.120003  35329300
# 2019-01-03 aapl     145.720001  142.000000  143.979996  142.190002  91312200
#            fb       137.169998  131.119995  134.690002  131.740005  22717900
#            msft     100.190002   97.199997  100.099998   97.400002  42579100
# 2019-01-04 aapl     148.550003  143.800003  144.529999  148.259995  58607100
#            fb       138.000000  133.750000  134.009995  137.949997  29002100
#            msft     102.510002   98.930000   99.720001  101.930000  44060600
# 2019-01-07 aapl     148.830002  145.899994  148.699997  147.929993  54777800
#            fb       138.869995  135.910004  137.559998  138.050003  20089300
#            msft     103.269997  100.980003  101.639999  102.059998  35656100
# 2019-01-08 aapl     151.820007  148.520004  149.559998  150.750000  41025300
#            fb       143.139999  139.539993  139.889999  142.529999  26263800
#            msft     103.970001  101.709999  103.040001  102.800003  31514400
# 2019-01-09 aapl     154.529999  149.630005  151.289993  153.309998  45099100
#            fb       144.699997  141.270004  142.949997  144.229996  22205900
#            msft     104.879997  103.239998  103.860001  104.269997  32280800
# 2019-01-10 aapl     153.970001  150.860001  152.500000  153.800003  35780700
#            fb       144.559998  140.839996  143.080002  144.199997  16125000
#            msft     103.750000  102.379997  103.220001  103.599998  30067600
# 2019-01-11 aapl     153.699997  151.509995  152.880005  152.289993  26976300
#            fb       145.360001  142.570007  143.149994  143.800003  12785900
#            msft     103.440002  101.639999  103.190002  102.800003  28242100
#
# Attributes           Adj Close
# Date       Symbols
# 2019-01-02 aapl     157.919998
#            fb       135.679993
#            msft     101.120003
# 2019-01-03 aapl     142.190002
#            fb       131.740005
#            msft      97.400002
# 2019-01-04 aapl     148.259995
#            fb       137.949997
#            msft     101.930000
# 2019-01-07 aapl     147.929993
#            fb       138.050003
#            msft     102.059998
# 2019-01-08 aapl     150.750000
#            fb       142.529999
#            msft     102.800003
# 2019-01-09 aapl     153.309998
#            fb       144.229996
#            msft     104.269997
# 2019-01-10 aapl     153.800003
#            fb       144.199997
#            msft     103.599998
# 2019-01-11 aapl     152.289993
#            fb       143.800003
#            msft     102.800003

# %%
ds=df.stack().reset_index()
ds
# Out:
# Attributes       Date Symbols        High         Low        Open       Close  \
# 0          2019-01-02    aapl  158.850006  154.229996  154.889999  157.919998
# 1          2019-01-02      fb  137.509995  128.559998  128.990005  135.679993
# 2          2019-01-02    msft  101.750000   98.940002   99.550003  101.120003
# 3          2019-01-03    aapl  145.720001  142.000000  143.979996  142.190002
# 4          2019-01-03      fb  137.169998  131.119995  134.690002  131.740005
# 5          2019-01-03    msft  100.190002   97.199997  100.099998   97.400002
# 6          2019-01-04    aapl  148.550003  143.800003  144.529999  148.259995
# 7          2019-01-04      fb  138.000000  133.750000  134.009995  137.949997
# 8          2019-01-04    msft  102.510002   98.930000   99.720001  101.930000
# 9          2019-01-07    aapl  148.830002  145.899994  148.699997  147.929993
# 10         2019-01-07      fb  138.869995  135.910004  137.559998  138.050003
# 11         2019-01-07    msft  103.269997  100.980003  101.639999  102.059998
# 12         2019-01-08    aapl  151.820007  148.520004  149.559998  150.750000
# 13         2019-01-08      fb  143.139999  139.539993  139.889999  142.529999
# 14         2019-01-08    msft  103.970001  101.709999  103.040001  102.800003
# 15         2019-01-09    aapl  154.529999  149.630005  151.289993  153.309998
# 16         2019-01-09      fb  144.699997  141.270004  142.949997  144.229996
# 17         2019-01-09    msft  104.879997  103.239998  103.860001  104.269997
# 18         2019-01-10    aapl  153.970001  150.860001  152.500000  153.800003
# 19         2019-01-10      fb  144.559998  140.839996  143.080002  144.199997
# 20         2019-01-10    msft  103.750000  102.379997  103.220001  103.599998
# 21         2019-01-11    aapl  153.699997  151.509995  152.880005  152.289993
# 22         2019-01-11      fb  145.360001  142.570007  143.149994  143.800003
# 23         2019-01-11    msft  103.440002  101.639999  103.190002  102.800003
#
# Attributes    Volume   Adj Close
# 0           37039700  157.919998
# 1           28146200  135.679993
# 2           35329300  101.120003
# 3           91312200  142.190002
# 4           22717900  131.740005
# 5           42579100   97.400002
# 6           58607100  148.259995
# 7           29002100  137.949997
# 8           44060600  101.930000
# 9           54777800  147.929993
# 10          20089300  138.050003
# 11          35656100  102.059998
# 12          41025300  150.750000
# 13          26263800  142.529999
# 14          31514400  102.800003
# 15          45099100  153.309998
# 16          22205900  144.229996
# 17          32280800  104.269997
# 18          35780700  153.800003
# 19          16125000  144.199997
# 20          30067600  103.599998
# 21          26976300  152.289993
# 22          12785900  143.800003
# 23          28242100  102.800003

# %%
ds.sort_values(['Symbols', 'Date'])
# Out:
# Attributes       Date Symbols        High         Low        Open       Close  \
# 0          2019-01-02    aapl  158.850006  154.229996  154.889999  157.919998
# 3          2019-01-03    aapl  145.720001  142.000000  143.979996  142.190002
# 6          2019-01-04    aapl  148.550003  143.800003  144.529999  148.259995
# 9          2019-01-07    aapl  148.830002  145.899994  148.699997  147.929993
# 12         2019-01-08    aapl  151.820007  148.520004  149.559998  150.750000
# 15         2019-01-09    aapl  154.529999  149.630005  151.289993  153.309998
# 18         2019-01-10    aapl  153.970001  150.860001  152.500000  153.800003
# 21         2019-01-11    aapl  153.699997  151.509995  152.880005  152.289993
# 1          2019-01-02      fb  137.509995  128.559998  128.990005  135.679993
# 4          2019-01-03      fb  137.169998  131.119995  134.690002  131.740005
# 7          2019-01-04      fb  138.000000  133.750000  134.009995  137.949997
# 10         2019-01-07      fb  138.869995  135.910004  137.559998  138.050003
# 13         2019-01-08      fb  143.139999  139.539993  139.889999  142.529999
# 16         2019-01-09      fb  144.699997  141.270004  142.949997  144.229996
# 19         2019-01-10      fb  144.559998  140.839996  143.080002  144.199997
# 22         2019-01-11      fb  145.360001  142.570007  143.149994  143.800003
# 2          2019-01-02    msft  101.750000   98.940002   99.550003  101.120003
# 5          2019-01-03    msft  100.190002   97.199997  100.099998   97.400002
# 8          2019-01-04    msft  102.510002   98.930000   99.720001  101.930000
# 11         2019-01-07    msft  103.269997  100.980003  101.639999  102.059998
# 14         2019-01-08    msft  103.970001  101.709999  103.040001  102.800003
# 17         2019-01-09    msft  104.879997  103.239998  103.860001  104.269997
# 20         2019-01-10    msft  103.750000  102.379997  103.220001  103.599998
# 23         2019-01-11    msft  103.440002  101.639999  103.190002  102.800003
#
# Attributes    Volume   Adj Close
# 0           37039700  157.919998
# 3           91312200  142.190002
# 6           58607100  148.259995
# 9           54777800  147.929993
# 12          41025300  150.750000
# 15          45099100  153.309998
# 18          35780700  153.800003
# 21          26976300  152.289993
# 1           28146200  135.679993
# 4           22717900  131.740005
# 7           29002100  137.949997
# 10          20089300  138.050003
# 13          26263800  142.529999
# 16          22205900  144.229996
# 19          16125000  144.199997
# 22          12785900  143.800003
# 2           35329300  101.120003
# 5           42579100   97.400002
# 8           44060600  101.930000
# 11          35656100  102.059998
# 14          31514400  102.800003
# 17          32280800  104.269997
# 20          30067600  103.599998
# 23          28242100  102.800003

# %%
ds[ds.Symbols=='fb']
# Out:
# Attributes       Date Symbols        High         Low        Open       Close  \
# 1          2019-01-02      fb  137.509995  128.559998  128.990005  135.679993
# 4          2019-01-03      fb  137.169998  131.119995  134.690002  131.740005
# 7          2019-01-04      fb  138.000000  133.750000  134.009995  137.949997
# 10         2019-01-07      fb  138.869995  135.910004  137.559998  138.050003
# 13         2019-01-08      fb  143.139999  139.539993  139.889999  142.529999
# 16         2019-01-09      fb  144.699997  141.270004  142.949997  144.229996
# 19         2019-01-10      fb  144.559998  140.839996  143.080002  144.199997
# 22         2019-01-11      fb  145.360001  142.570007  143.149994  143.800003
#
# Attributes    Volume   Adj Close
# 1           28146200  135.679993
# 4           22717900  131.740005
# 7           29002100  137.949997
# 10          20089300  138.050003
# 13          26263800  142.529999
# 16          22205900  144.229996
# 19          16125000  144.199997
# 22          12785900  143.800003

# %%
sns.lineplot(x='Date', y='Adj Close', hue='Symbols',
             style='Symbols',
             data=ds);

# %%
sns.relplot(x='Date', y='Adj Close', col='Symbols',
            hue='Symbols',
            kind='line',
            height=5,
            facet_kws={'sharey': False},
            data=ds)

# %%
sns.lineplot(x='Date', y='Adj Close', hue='Symbols',
             data=ds[ds.Symbols.str.match('aapl|msft')]);

# %%
ds.to_csv('port1.csv', index=False)
ds.to_excel('port1.xlsx', index=False)
